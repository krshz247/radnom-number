# %%
include("Quasi_random.jl")
using Plots

# %% [markdown]
# ## Harmonious numbers

# %%
for i in 1:8
    H = Harmonious_number(i::Int)
    println("d = $i; ϕ = $H") 
end
# Out:
# d = 1; ϕ = 1.6180339887498947
# d = 2; ϕ = 1.324717957244746
# d = 3; ϕ = 1.2207440846057596
# d = 4; ϕ = 1.1673039782614185
# d = 5; ϕ = 1.1347241384015194
# d = 6; ϕ = 1.1127756842787053
# d = 7; ϕ = 1.09698155779856
# d = 8; ϕ = 1.0850702454914505

# %% [markdown]
# ## $R_2$ Sequence

# %%
N = 10 # Number of random numbers generated
d = 2  # Harmonious number (dimentions)
S₀ = 0
R_2 = R_n_sequence(S₀, d, N)
R_2'
# Out:
# 10×2 adjoint(::Matrix{Float64}) with eltype Float64:
#  0.754878   0.56984
#  0.509755   0.139681
#  0.264633   0.709521
#  0.0195107  0.279361
#  0.774388   0.849201
#  0.529266   0.419042
#  0.284144   0.988882
#  0.0390213  0.558722
#  0.793899   0.128563
#  0.548777   0.698403

# %% [markdown]
# # 2D Plot

# %%
N = 1000
d = 2
S₀ = 0

R_2 = R_n_sequence(S₀, d, N)

x = R_2[1, :]
y = R_2[2, :]

scatter(x, y, mode="markers")
